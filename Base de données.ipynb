# %% [markdown]
# # SQLite Connection

# %%
# !pip install sqlalchemy==2.0.21
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import sqlalchemy as db

db.__version__
# Out:
# '2.0.21'

# %%
from functions import DataBaseV2

# Création d'une base de données
database = DataBaseV2(db_name='test', db_type='sqlite')

# %%
# Création d'un Tableau1
database.create_table('Tableau1', 
                      id_=db.Integer, 
                      colonne1=db.String, 
                      colonne2=db.Integer)
# Out:
# Table : 'Tableau1' are created succesfully

# %%
db.DATE
# Out:
# sqlalchemy.sql.sqltypes.DATE

# %%
db.DateTime
# Out:
# sqlalchemy.sql.sqltypes.DateTime

# %%
# Création d'un Tableau2
database.create_table('Tableau2', id_shop=db.Integer, id_colonne1=db.String, colonne2=db.Integer)
# Out:
# Table : 'Tableau2' are created succesfully

# %%
database.table
# Out:
# ['Tableau1', 'Tableau2']

# %%
# Ajouter une ligne à la base de données
database.add_row('Tableau2', id_shop=68, id_colonne1='Iphone')
# Out:
# Row id added

# %%
# Ajouter plusieurs lignes à la base de données
for i in range(10):
    database.add_row('Tableau2',id_shop=i, id_colonne1='Iphone'*(i+1), colonne2=99*i)
# Out:
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added

# %%
# Afficher le Tableau1
database.select_table('Tableau2')
# Out:
# [(306, 'Iphone', 3000),
#  (0, 'Iphone', 0),
#  (1, 'IphoneIphone', 99),
#  (2, 'IphoneIphoneIphone', 198),
#  (3, 'IphoneIphoneIphoneIphone', 297),
#  (4, 'IphoneIphoneIphoneIphoneIphone', 396),
#  (5, 'IphoneIphoneIphoneIphoneIphoneIphone', 495),
#  (6, 'IphoneIphoneIphoneIphoneIphoneIphoneIphone', 594),
#  (7, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 693),
#  (8, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 792),
#  (9, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 891)]

# %%
# Supprimer une ligne de la base de données
database.delete_row_by_id('Tableau2', 7)
# Out:
# id_shop
# Row with id 7 deleted

# %%
# Supprimer un Tableau de la base de données
database.delete_table('Tableau1')
# Out:
# Table Tableau1 deleted successfully

# %%
# Afficher les tables de la base de données
database.table
# Out:
# ['Tableau2']

# %%
# Lire un Tableau de la base de données au format sqlalchemy
database.read_table('Tableau2')
# Out:
# Table('Tableau2', MetaData(), Column('id_shop', Integer(), table=<Tableau2>, primary_key=True, nullable=False), Column('id_colonne1', String(), table=<Tableau2>, primary_key=True, nullable=False), Column('colonne2', Integer(), table=<Tableau2>), schema=None)

# %%
# Lire un Tableau de la base de données au format pandas
database.dataframe('Tableau2')
# Out:
#    id_shop                                        id_colonne1  colonne2  \
# 0        0                                             Iphone         0
# 1        1                                       IphoneIphone        99
# 2        2                                 IphoneIphoneIphone       198
# 3        3                           IphoneIphoneIphoneIphone       297
# 4        4                     IphoneIphoneIphoneIphoneIphone       396
# 5        5               IphoneIphoneIphoneIphoneIphoneIphone       495
# 6        6         IphoneIphoneIphoneIphoneIphoneIphoneIphone       594
# 7        7   IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone       693
# 8        8  IphoneIphoneIphoneIphoneIphoneIphoneIphoneIpho...       792
# 9        9  IphoneIphoneIphoneIphoneIphoneIphoneIphoneIpho...       891
#
#   colonne3 colonne4
# 0     None     None
# 1     None     None
# 2     None     None
# 3     None     None
# 4     None     None
# 5     None     None
# 6     None     None
# ...

# %%
from functions.DataBaseV2 import create_table
import sqlalchemy as db

# Création d'une base de données
database = DataBaseV2(db_name='test', db_type='sqlite')

# %%
DataBaseV2().create_table

# %%
# Add colomumn3 in Tableau2 with SQL request
database.send_query(f'ALTER TABLE {table} ADD COLUMN {column} INTEGER')

# %%
database.read_table('Tableau2').columns.keys()
# Out:
# ['id_shop', 'id_colonne1', 'colonne2']

# %%
# Get file from github https://github.com/Quera-fr/Base-de-Donnee/blob/main/functions.py

# !wget https://raw.githubusercontent.com/Quera-fr/Base-de-Donnee/main/functions.py
# Out:
# --2024-02-08 14:29:19--  https://raw.githubusercontent.com/Quera-fr/Base-de-Donnee/main/functions.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 7843 (7,7K) [text/plain]
# Sauvegarde en : « functions.py.1 »
#
# functions.py.1      100%[===================>]   7,66K  --.-KB/s    ds 0,005s
#
# 2024-02-08 14:29:19 (1,37 MB/s) — « functions.py.1 » sauvegardé [7843/7843]

# %%
import requests

url = 'https://raw.githubusercontent.com/Quera-fr/Base-de-Donnee/main/functions.py'
open('functions2.py', 'wb').write(requests.get(url).content)
# Out:
# 7843

# %%
from functions2 import DataBaseV1

# %%
DataBaseV1
# Out:
# functions2.DataBaseV1

# %%
database.dataframe('Tableau2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 database.dataframe('Tableau2')
#
# NameError: name 'database' is not defined

# %% [markdown]
# # My SQL Database

# %%
# !pip install pymysql
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from functions import DataBaseV2

name_db = 'amazon'
host = '0.0.0.0'
port = '8889'
user = 'root'
password = 'root'



database = DataBaseV2(
    db_name=name_db,
    db_type='mysql',
    db_port=port,
    db_user=user,
    db_password=password,
    db_host=host,
    db_url=None
)

# %%
database.table
# Out:
# ['categorie', 'search']

# %%
database.dataframe("search")
# Out:
#       id                                              title       price  \
# 0      1                  Apple iPhone 14 (128 Go) - Minuit    990,00 €
# 1      2               Apple iPhone 14 Plus (512 Go) - Bleu  1 559,00 €
# 2      3                  Apple iPhone 14 Pro (128 Go) - Or  1 329,00 €
# 3      4              Apple iPhone 12 Mini (128 Go) - Blanc    639,00 €
# 4      5                    Apple iPhone 13 (128 Go) - Bleu    849,00 €
# ..   ...                                                ...         ...
# 255  256  Xiaomi Redmi Note 11 Pro 5G - Smartphone 128GB...    281,00 €
# 256  257  Xiaomi 12 Pro 5G - Smartphone 12+256GB, Écran ...  1 065,04 €
# 257  258              Samsung A3 2016 16 GO (Reconditionné)     99,00 €
# 258  259  Xiaomi Poco M3 Pro 5G - Smartphone Débloqué 5G...    215,99 €
# 259  260  Xiaomi Redmi Note 11s - Smartphone 128GB, 6GB ...    214,00 €
#
#               notation nbnotation  \
# 0    4,4 sur 5 étoiles        217
# ...

# %%
# Afficher les tables de la base de données sous forme de dictionnaire
database.show_tables_infos()
# Out:
# {'search': Table('search', MetaData(), Column('id', INTEGER(display_width=11), table=<search>, primary_key=True, nullable=False), Column('title', VARCHAR(length=255), table=<search>), Column('price', VARCHAR(length=255), table=<search>), Column('notation', MEDIUMTEXT(), table=<search>), Column('nbnotation', VARCHAR(length=255), table=<search>), Column('link', MEDIUMTEXT(), table=<search>), schema=None),
#  'categorie': Table('categorie', MetaData(), Column('id', INTEGER(display_width=11), table=<categorie>, primary_key=True, nullable=False), Column('title', VARCHAR(length=255), table=<categorie>), Column('price', VARCHAR(length=255), table=<categorie>), Column('notation', MEDIUMTEXT(), table=<categorie>), Column('nbnotation', VARCHAR(length=255), table=<categorie>), Column('link', MEDIUMTEXT(), table=<categorie>), schema=None)}

# %% [markdown]
# # PostgreSQL Database

# %%
# !pip install psycopg2-binary
# Out:
# ...
#   Obtaining dependency information for psycopg2-binary from https://files.pythonhosted.org/packages/7a/1f/a6cf0cdf944253f7c45d90fbc876cc8bed5cc9942349306245715c0d88d6/psycopg2_binary-2.9.9-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached psycopg2_binary-2.9.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.4 kB)
# Using cached psycopg2_binary-2.9.9-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import sqlalchemy as db

db.__version__
# Out:
# '2.0.21'

# %%
import sqlalchemy as db


data_type = {
    'int64' : db.INTEGER,
    'float64' : db.FLOAT,
    'object' : db.String,
    'datetime64' : db.DateTime,
    'bool' : db.Boolean,
    'category' : db.String    
}

# %%
from functions import DataBaseV2

dbname = 'd1dcrr60p484dk'
host = 'ec2-54-73-103-21.eu-west-1.compute.amazonaws.com'
port = '5432'
user = 'mqnvdkpvcofzld'
password = '91fb99bacc7e38d371cd7e96e3b5b15967ce099bfc393b3ec1c3dd1502069cbf'

database = DataBaseV2(
    db_type='postgresql',
    #db_name=dbname,
    #db_host=host,
    #db_port=port,
    #db_user=user,
    #db_password=password
    db_url="postgresql://mqnvdkpvcofzld:91fb99bacc7e38d371cd7e96e3b5b15967ce099bfc393b3ec1c3dd1502069cbf@ec2-54-73-103-21.eu-west-1.compute.amazonaws.com:5432/d1dcrr60p484dk"
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3288, in Engine.raw_connection(self)
#    3267 """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269 The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287 """
# -> 3288 return self.pool.connect()
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
# ...

# %%
database.table
# Out:
# ['alembic_version',
#  'experiment_tags',
#  'latest_metrics',
#  'metrics',
#  'input_tags',
#  'inputs',
#  'model_versions',
#  'registered_model_tags',
#  'tags',
#  'params',
#  'registered_models',
#  'registered_model_aliases',
#  'experiments',
#  'datasets',
#  'runs',
#  'model_version_tags',
#  'Alerts']

# %%
SELECT MAX(value) FROM metrics LIMIT 50
 
SELECT MAX(value) FROM metrics WHERE key="train_r2" LIMIT 50

# %%
# Get colonne "value" from "metrics" table wher value > 0.5
database.query_to_dataframe("SELECT value FROM metrics WHERE value > 0.5")
# Out:
# Error: Query not executed

# %%
database.dataframe('metrics')
# Out:
#                                   key     value      timestamp  \
# 0         training_mean_squared_error  0.036527  1699489954892
# 1        training_mean_absolute_error  0.123705  1699489954892
# 2                   training_r2_score  0.972526  1699489954892
# 3    training_root_mean_squared_error  0.191121  1699489954892
# 4                      training_score  0.972526  1699489955436
# ..                                ...       ...            ...
# 238                    training_score  0.998922  1706708117108
# 239            Pipeline_score_X_train  0.998922  1706708125321
# 240                       train_score  0.998922  1706708130126
# 241                       train_score  0.998949  1706707770163
# 242           Pipeline_score-3_X_test  0.885989  1706708220688
#
#                              run_uuid  step  is_nan
# 0    ed3ab399185c405f89988a80f2d1251e     0   False
# 1    ed3ab399185c405f89988a80f2d1251e     0   False
# ...

# %%
infos = database.show_tables_infos()
infos
# Out:
# {'alembic_version': Table('alembic_version', MetaData(), Column('version_num', VARCHAR(length=32), table=<alembic_version>, primary_key=True, nullable=False), schema=None),
#  'experiment_tags': Table('experiment_tags', MetaData(), Column('key', VARCHAR(length=250), table=<experiment_tags>, primary_key=True, nullable=False), Column('value', VARCHAR(length=5000), table=<experiment_tags>), Column('experiment_id', INTEGER(), ForeignKey('experiments.experiment_id'), table=<experiment_tags>, primary_key=True, nullable=False), schema=None),
# ...

# %%
database.dataframe('inputs')
# Out:
#                           input_uuid source_type  \
# 0   f3555f48b372446694931645a44837ea     DATASET
# 1   2c1df03a3cdc49b89b233f2f50d4d949     DATASET
# 2   bcf1ec194e1348e496bcb75b7e1a34c2     DATASET
# 3   f37c6d62795048a4b65eef66f11e725a     DATASET
# 4   2f1b9a093d424d2790eaed94edaaaeeb     DATASET
# 5   824ab4d0590b45249f600e9bb9cf030b     DATASET
# 6   c6b9cfeba8b043ccb4dac50cbcdaac0c     DATASET
# 7   26f4040b323b4c5c9a17696460b74bde     DATASET
# 8   94c84b5481944c1a95069048c58f260f     DATASET
# 9   c558beabd6f34ee795bee1407f6d4640     DATASET
# 10  e9acf9f59bec4a11afbf973b4ff2524e     DATASET
# 11  c0be665040fc43338a093984a1f537e7     DATASET
# 12  730ca4cdf2054facba868630a0253093     DATASET
# 13  3b3740f16c954a2fa286895d7ab978b1     DATASET
# 14  27145629ba7345f880593c7c6bf227d4     DATASET
# 15  f78c6d9a23814b59a0fe53785ec36b74     DATASET
# 16  7c264ab1b75f4658a9b61be4ad2e78b5     DATASET
# 17  d5635349502e404dbaa5a55619569bf0     DATASET
# ...

# %%
# List requierments with pipreqs
# !pip install pipreqs
# !pipreqs .
# Out:
# ...
#   Using cached pipreqs-0.4.13-py2.py3-none-any.whl (33 kB)
# ...
#   Using cached yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# WARNING: Import named "pandas" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pandas" was resolved to "pandas:2.2.0" package (https://pypi.org/project/pandas/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# INFO: Successfully saved requirements file in ./requirements.txt

# %%
from functions import DataBaseV2
import sqlalchemy as db
import pandas as pd

df = pd.read_csv('test.csv', sep=';')

database = DataBaseV2(
    db_type='sqlite',
    db_name = 'Test'
)

# %%
database.dataframe_to_table('Table', df)
# Out:
# {'age': <class 'sqlalchemy.sql.sqltypes.INTEGER'>, 'job': <class 'sqlalchemy.sql.sqltypes.String'>, 'marital': <class 'sqlalchemy.sql.sqltypes.String'>, 'education': <class 'sqlalchemy.sql.sqltypes.String'>, 'default': <class 'sqlalchemy.sql.sqltypes.String'>, 'balance': <class 'sqlalchemy.sql.sqltypes.INTEGER'>, 'housing': <class 'sqlalchemy.sql.sqltypes.String'>, 'loan': <class 'sqlalchemy.sql.sqltypes.String'>, 'contact': <class 'sqlalchemy.sql.sqltypes.String'>, 'day': <class 'sqlalchemy.sql.sqltypes.INTEGER'>, 'month': <class 'sqlalchemy.sql.sqltypes.String'>, 'duration': <class 'sqlalchemy.sql.sqltypes.INTEGER'>, 'campaign': <class 'sqlalchemy.sql.sqltypes.INTEGER'>, 'pdays': <class 'sqlalchemy.sql.sqltypes.INTEGER'>, 'previous': <class 'sqlalchemy.sql.sqltypes.INTEGER'>, 'poutcome': <class 'sqlalchemy.sql.sqltypes.String'>, 'y': <class 'sqlalchemy.sql.sqltypes.String'>}
# Table : 'Table' are created succesfully
# Row id added
# Row id added
# Row id added
# Row id added
# ...
